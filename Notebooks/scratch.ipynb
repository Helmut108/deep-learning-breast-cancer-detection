# %%
import multiprocessing

n_workers = multiprocessing.cpu_count()

# %%
n_workers
# Out:
# 10

# %%
import polars as pl
pl.__version__
# Out:
# '1.37.1'

# %%
 
df = pl.DataFrame({
    "name": ["Alice", "Bob", "Charlie"],
    "age": [25, 30, 35],
    "salary": [50000, 60000, 70000]
})
 
print(df)
# Out:
# shape: (3, 3)
# ┌─────────┬─────┬────────┐
# │ name    ┆ age ┆ salary │
# │ ---     ┆ --- ┆ ---    │
# │ str     ┆ i64 ┆ i64    │
# ╞═════════╪═════╪════════╡
# │ Alice   ┆ 25  ┆ 50000  │
# │ Bob     ┆ 30  ┆ 60000  │
# │ Charlie ┆ 35  ┆ 70000  │
# └─────────┴─────┴────────┘

# %%
# Source - https://stackoverflow.com/a/61598951
# Posted by Szymon Maszke, modified by community. See post 'Timeline' for change history
# Retrieved 2026-04-16, License - CC BY-SA 4.0

import torch

tensor = torch.tensor([1, 0, 2, 3, 4])
tensor.shape # torch.Size([5])
tensor.unsqueeze(dim=0).shape # [1, 5]
tensor.unsqueeze(dim=1).shape # [5, 1]
# Out:
# torch.Size([5, 1])

# %%
tensor = torch.tensor([1, 0, 2, 3, 4])
tensor
# Out:
# tensor([1, 0, 2, 3, 4])

# %%
tensor.shape
# Out:
# torch.Size([5])

# %%
x = tensor.unsqueeze(dim=0)

x

x
# Out:
# tensor([[1, 0, 2, 3, 4]])

# %%
x = tensor.unsqueeze(dim=1)

x
# Out:
# tensor([[1],
#         [0],
#         [2],
#         [3],
#         [4]])

# %%
x.squeeze(dim=1)
x
# Out:
# tensor([[1],
#         [0],
#         [2],
#         [3],
#         [4]])

# %%
import torch
import torch.nn as nn

class MinimalCNN(nn.Module):
    def __init__(self):
        super(MinimalCNN, self).__init__()
        # 1. Define the layers here
        
    def forward(self, x):
        # 2. Define the flow of data (the forward pass)
        return x

# %%
import torch
a = torch.randn(4, 4)
a
torch.tensor([[ 1.3398,  0.2663, -0.2686,  0.2450],
        [-0.7401, -0.8805, -0.3402, -1.1936],
        [ 0.4907, -1.3948, -1.0691, -0.3132],
        [-1.6092,  0.5419, -0.2993,  0.3195]])
torch.argmax(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 9
#       4 torch.tensor([[ 1.3398,  0.2663, -0.2686,  0.2450],
#       5         [-0.7401, -0.8805, -0.3402, -1.1936],
#       6         [ 0.4907, -1.3948, -1.0691, -0.3132],
#       7         [-1.6092,  0.5419, -0.2993,  0.3195]])
#       8 torch.argmax(a)
# ----> 9 tensor(0)
#
# NameError: name 'tensor' is not defined

# %%
a = torch.tensor([[ 1.3398,  0.2663, -0.2686,  0.2450],
        [-0.7401, -0.8805, -0.3402, -1.1936],
        [ 0.4907, -1.3948, -1.0691, -0.3132],
        [-1.6092,  0.5419, -0.2993,  0.3195]])

parg = torch.argmax(a, dim=1)
print("argmax:", parg)
print()
pmax = torch.max(a, dim=1)
print("max:", pmax)
# Out:
# argmax: tensor([0, 2, 0, 1])
#
# max: torch.return_types.max(
# values=tensor([ 1.3398, -0.3402,  0.4907,  0.5419]),
# indices=tensor([0, 2, 0, 1]))

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("cheddad/miniddsm2")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 49.1G/49.1G [1:31:12<00:00, 9.63MB/s]
# Extracting files...

# %%
val_acc = [54.6875, 54.6875, 52.734375, 54.296875, 55.078125, 52.734375, 55.859375, 57.421875, 58.203125, 60.9375, 54.6875, 59.765625, 58.984375, 62.109375, 61.328125, 61.328125, 59.375, 58.984375, 60.15625, 61.328125, 60.9375, 59.765625, 60.15625, 60.9375, 62.109375, 62.109375, 60.15625, 61.328125, 59.375, 61.328125]
type(val_acc)
# Out:
# list

# %%
from statistics import mean, mode, multimode, StatisticsError

avg = mean(val_acc)      # mean
mx = max(val_acc)        # max
mn = min(val_acc)        # minval_acc
mode_val = mode(val_acc)  # mode

print("Mean:", avg)
print("Max:", mx)
print("Min:", mn)
print("Mode:", mode_val)
# Out:
# Mean: 58.763020833333336
# Max: 62.109375
# Min: 52.734375
# Mode: 61.328125

# %%
patience=5
type(patience)
# Out:
# int

# %%
# 50 epochs
Training Loss History: [0.6976771292186552, 0.6935919268477347, 0.6899618232442487, 0.6869522592713756, 0.6849785600939104, 0.6800020894696636, 0.6786855012178421, 0.677033410918328, 0.6728328461608579, 0.6695935481017635, 0.6651811801618145, 0.6647822635789071, 0.6625097331500822, 0.6603111826604412, 0.6596077964190514, 0.6587194134631464, 0.6549193455326942, 0.6545811057571442, 0.6529452863239473, 0.6501887137851408]
Training Accuracy History: [50.40485829959515, 52.125506072874494, 53.64372469635627, 55.66801619433198, 55.06072874493927, 58.502024291497975, 56.68016194331984, 56.78137651821862, 56.78137651821862, 59.91902834008097, 61.03238866396761, 61.63967611336032, 60.32388663967612, 59.81781376518218, 60.93117408906883, 60.627530364372475, 61.53846153846154, 61.03238866396761, 61.43724696356275, 61.8421052631579]
Validation Loss History: [0.6897759934266409, 0.6860600738298326, 0.6970451105208624, 0.6821385948430925, 0.6806191447235289, 0.6757920668238685, 0.6724637079806555, 0.6719732128438496, 0.6679470340410868, 0.666292035863513, 0.6646662198361897, 0.6638791440498262, 0.6637083895149685, 0.6630307705629439, 0.6609854627223242, 0.661194118715468, 0.6648882528146108, 0.6662034505889529, 0.6633017389547258, 0.6649815738201141]
Validation Accuracy History: [51.81818181818182, 53.03030303030303, 48.18181818181818, 61.81818181818181, 52.72727272727272, 55.15151515151515, 58.78787878787879, 54.54545454545454, 60.303030303030305, 60.303030303030305, 63.33333333333333, 59.09090909090909, 56.96969696969697, 63.33333333333333, 60.909090909090914, 60.0, 62.42424242424243, 63.030303030303024, 62.42424242424243, 58.484848484848484]

# %%
from statistics import mean, mode, multimode, StatisticsError
test_list = [0.6914917514437721, 0.6869107271943774, 0.6839970066433861, 0.6839347240470705, 0.677789283650262, 0.6748959734326317, 0.6721103617123195, 0.6715881625811259, 0.6711006987662542, 0.6705679481937772, 0.6686557715847379, 0.6657331983248392, 0.6815754175186157, 0.6717133891014826, 0.6628856800851368, 0.6654734568936485, 0.6628643217540923, 0.6616785143102918, 0.6593768766948155, 0.6602204889059067, 0.6636969801925477, 0.6588165958722433, 0.6604746182759603, 0.6606604201453072, 0.6584162201200213, 0.6582347814525876, 0.6559743256795973, 0.6575171110175905, 0.65928373166493, 0.6567818969488144, 0.6605585260050637, 0.662057699901717, 0.6697142039026532, 0.6715599468776158, 0.6496549880220777, 0.6533406596808207, 0.688390239363625, 0.6511631302890324, 0.6479674251306624, 0.6463646335261208, 0.6524894996767953, 0.6512338866790136, 0.6708684705552601, 0.6564502737351826, 0.6449232555571056, 0.6507051211027872, 0.6847279802674339, 0.6440190672874451, 0.6432441260133471, 0.6637969130561465]

# test_list = val_acc_history
avg = mean(test_list)      # mean
mx = max(test_list)        # max
mn = min(test_list)        # min
mode_val = mode(test_list)  # mode

605585260050637, 0.662057699901717, 0.6697142039026532, 0.6715599468776158, 0.6496549880220777, 0.6533406596808207, 0.688390239363625, 0.6511631302890324, 0.6479674251306624, 0.6463646335261208, 0.6524894996767953, 0.6512338866790136, 0.6708684705552601, 0.6564502737351826, 0.6449232555571056, 0.6507051211027872, 0.6847279802674339, 0.6440190672874451, 0.6432441260133471, 0.6637969130561465]
# Validation Accuracy History: [49.09090909090909, 58.18181818181818, 52.72727272727272, 59.696969696969695, 56.96969696969697, 57.27272727272727, 55.757575757575765, 55.757575757575765, 54.848484848484844, 60.60606060606061, 55.757575757575765, 61.51515151515151, 60.909090909090914, 61.212121212121204, 59.09090909090909, 63.33333333333333, 61.51515151515151, 58.78787878787879, 60.60606060606061, 59.3939393939394, 61.81818181818181, 62.121212121212125, 58.78787878787879, 62.121212121212125, 61.212121212121204, 60.60606060606061, 61.81818181818181, 60.0, 58.484848484848484, 59.3939393939394, 58.78787878787879, 57.878787878787875, 63.33333333333333, 56.36363636363636, 62.727272727272734, 60.60606060606061, 60.60606060606061, 62.121212121212125, 60.60606060606061, 63.33333333333333, 59.09090909090909, 63.63636363636363, 63.63636363636363, 63.030303030303024, 63.63636363636363, 61.212121212121204, 58.18181818181818, 61.212121212121204, 63.030303030303024, 59.09090909090909]
val_acc_history = [49.09090909090909, 58.18181818181818, 52.72727272727272, 59.696969696969695, 56.96969696969697, 57.27272727272727, 55.757575757575765, 55.757575757575765, 54.848484848484844, 60.60606060606061, 55.757575757575765, 61.51515151515151, 60.909090909090914, 61.212121212121204, 59.09090909090909, 63.33333333333333, 61.51515151515151, 58.78787878787879, 60.60606060606061, 59.3939393939394, 61.81818181818181, 62.121212121212125, 58.78787878787879, 62.121212121212125, 61.212121212121204, 60.60606060606061, 61.81818181818181, 60.0, 58.484848484848484, 59.3939393939394, 58.78787878787879, 57.878787878787875, 63.33333333333333, 56.36363636363636, 62.727272727272734, 60.60606060606061, 60.60606060606061, 62.121212121212125, 60.60606060606061, 63.33333333333333, 59.09090909090909, 63.63636363636363, 63.63636363636363, 63.030303030303024, 63.63636363636363, 61.212121212121204, 58.18181818181818, 61.212121212121204, 63.030303030303024, 59.09090909090909]

# %%
len(train_loss_history)
# Out:
# 50

# %%
train_loss_history[0]
# Out:
# 0.695008449977444

# %%
import matplotlib.pyplot as plt

# %%
epochs_range = range(1, len(train_loss_history) + 1)
plt.figure(figsize=(8, 4))
plt.plot(epochs_range, train_loss_history, marker='o', label='Train Loss')
plt.plot(epochs_range, val_loss_history, marker='o', label='Val Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training vs Validation Loss')
plt.grid(True, linestyle='--', alpha=0.5)
# plt.axvline(x = best_epoch, color = 'g', label = 'best epoch', linestyle='--')

plt.legend()
plt.tight_layout()
plt.show()

# %%
val_loss_history[-1]
# Out:
# 0.6637969130561465

# %%
val_loss_history[44:50]
# Out:
# [0.6449232555571056,
#  0.6507051211027872,
#  0.6847279802674339,
#  0.6440190672874451,
#  0.6432441260133471,
#  0.6637969130561465]

# %%
import matplotlib.pyplot as plt

# %%
best_epoch = 49

# %%
epochs_range = range(1, len(train_loss_history) + 1)
plt.figure(figsize=(8, 4))
plt.plot(epochs_range, train_loss_history, marker='o', label='Train Loss')
plt.plot(epochs_range, val_loss_history, marker='o', label='Val Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training vs Validation Loss')
plt.grid(True, linestyle='--', alpha=0.5)
plt.axvline(x = best_epoch, color = 'g', label = 'best epoch', linestyle='--')

plt.legend()
plt.tight_layout()
plt.show()
